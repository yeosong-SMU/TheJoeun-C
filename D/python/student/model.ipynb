# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
import joblib
import matplotlib.pyplot as plt

df = pd.read_csv("d:/data/student/student-mat.csv", sep=';')

features = ['age', 'studytime', 'failures', 'absences', 'G1', 'G2', 'Medu', 'Fedu']
X = df[features]
y = df['G3']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

model = LinearRegression()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)
print("R2 score: ", r2_score(y_test, y_pred))

joblib.dump(model, "d:/data/student/student_score_model.pkl")

plt.figure(figsize=(10, 6))
plt.barh(features, model.coef_)
plt.title("Feature Coefficients (Linear Regression)")
plt.xlabel("Coefficient")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# R2 score:  0.8153881711749625
