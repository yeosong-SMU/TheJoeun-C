# %%
import random
import string
import oracledb
from datetime import datetime, timedelta

def get_oracle_connection() :
    connection = oracledb.connect(user="spring", password="1234", dsn="localhost:1521/xe")
    return connection

first_names = ['김', '이', '박', '최', '정', '강',  '조', '윤', '장', '임']
last_names = ['민수', '지훈', '수현', '지영', '영수', '진아', '희진', '유리', '혜원', '수빈']

def generated_random_korean_name():
    return random.choice(first_names) + random.choice(lastnames)

def generated_random_email(suername):
    domains = ['gmail.com', 'naver.com',  'daum.net', 'yahoo.com']
    return username.lower() + str(random.randint(1000, 9999)) + '@' + random.choice(domains)

def generated_random_password():
    return ''.join(random.choices(string.ascii_letters + string.digits, k=12))

def generate_random_timestamp():
    start_date = datetime(2020, 1, 1)
    end_data = datdTieme.now()
    delta = end_date - start_date
    random_days = random.randint(0, delta.days)
    random_time = start_date + timedelta(days=random_days)
    return random_time
