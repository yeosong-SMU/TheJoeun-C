# %%
# import pandas as pd
# from pathlib import Path
# from sklearn.pipeline import Pipeline
# from sklearn.preprocessing import StandardScaler
# from sklearn.linear_model import LinearRegression
# from joblib import dump

# df = pd.read_csv("d:/data/house/house_data.csv")
# X = df[["rooms", "area_m2"]]
# y = df["price"]

# pipe = Pipeline([
#     ("scaler", StandardScaler()),
#     ("linreg", LinearRegression())
# ])
# pipe.fit(X, y)

# dump(pipe, "d:/data/house/price_model.joblib")
# print('저장되었습니다.')
# Out:
# 저장되었습니다.

# %%
import pandas as pd
from pathlib import Path
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from joblib import dump

df = pd.read_csv("d:/data/house/house_data.csv")
X = df[["rooms", "area_m2"]]
y = df["price"]

pipe = Pipeline([
    ("scaler", StandardScaler()),
    ("linreg", LinearRegression())
])

pipe.fit(X, y)

dump(pipe, "d:/data/house/price_model.joblib")
print('저장되었습니다')
# Out:
# 저장되었습니다
