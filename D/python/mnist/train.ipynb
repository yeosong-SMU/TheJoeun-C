# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPool2D, Flatten, Dense

(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
#3차원 데이터를 4차원 데이터로 확장, ...앞의 차원은 그대로 유지
x_train = (x_train / 255.0).astype("float32")[..., None]
x_test = (x_test / 255.0).astype("float32")[..., None]

model = Sequential([
    Input(shape=(28, 28, 1)),
    Conv2D(32, 3, activation="relu"),
    MaxPool2D(),
    Conv2D(64, 3, activation="relu"),
    MaxPool2D(),
    Flatten(),
    Dense(128, activation="relu"),
    Dense(10, activation="softmax"),
])

model.compile(optimizer="adam", 
            loss="sparse_categorical_crossentropy", 
            metrics=["accuracy"])
model.fit(x_train, y_train, epochs=3, batch_size=128,
        validation_data=(x_test, y_test), verbose=2)

out_path = "d:/data/mnist/mnist_cnn.keras"
model.save(out_path)
print(f"saved: {out_path}")
# Out:
# Epoch 1/3
# 469/469 - 11s - 23ms/step - accuracy: 0.9357 - loss: 0.2162 - val_accuracy: 0.9801 - val_loss: 0.0623
# Epoch 2/3
# 469/469 - 10s - 20ms/step - accuracy: 0.9830 - loss: 0.0567 - val_accuracy: 0.9867 - val_loss: 0.0417
# Epoch 3/3
# 469/469 - 9s - 20ms/step - accuracy: 0.9890 - loss: 0.0367 - val_accuracy: 0.9879 - val_loss: 0.0342
# saved: d:/data/mnist/mnist_cnn.keras
